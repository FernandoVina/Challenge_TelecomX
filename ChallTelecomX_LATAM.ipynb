# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoVina/Challenge_TelecomX/blob/main/ChallTelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos_telecom = pd.read_json('/content/TelecomX_Data.json')
datos_telecom.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
datos_telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos_telecom.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
datos_telecom.shape
# Out:
# (7267, 6)

# %%
type(datos_telecom)
# Out:
# pandas.core.frame.DataFrame

# %%
columnas = list(datos_telecom.columns)
columnas
# Out:
# ['customerID', 'Churn', 'customer', 'phone', 'internet', 'account']

# %%
# se normaliza las columnas correspondientes
customer_data = pd.json_normalize(datos_telecom['customer'])
phone_data = pd.json_normalize(datos_telecom['phone'])
internet_data = pd.json_normalize(datos_telecom['internet'])
account_data = pd.json_normalize(datos_telecom['account'])

# Concatenando el nuevo dataframe con el original dataframe
datos_telecom_expanded = pd.concat([datos_telecom[['customerID', 'Churn']], customer_data, phone_data, internet_data, account_data], axis=1)

display(datos_telecom_expanded.head())
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
datos_telecom_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
datos_telecom_expanded['Charges.Total'] = pd.to_numeric(datos_telecom_expanded['Charges.Total'], errors='coerce')
# errors='coerce' se aseguró de que cualquier valor en esa columna que no pudiera ser convertido a número
 # (como cadenas vacías o texto) fuera reemplazado por NaN (Not a Number), que representa valores faltantes.

# %%
datos_telecom_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# # **Diccionario de datos**
# customerID: número de identificación único de cada cliente,
# Churn: si el cliente dejó o no la empresa,
# gender: género (masculino y femenino),
# SeniorCitizen: información sobre si un cliente tiene o no una edad igual o mayor a 65 años,
# Partner: si el cliente tiene o no una pareja,
# Dependents: si el cliente tiene o no dependientes,
# tenure: meses de contrato del cliente,
# PhoneService: suscripción al servicio telefónico,
# MultipleLines: suscripción a más de una línea telefónica,
# InternetService: suscripción a un proveedor de internet
# OnlineSecurity: suscripción adicional de seguridad en línea,
# OnlineBackup: suscripción adicional de respaldo en línea,
# DeviceProtection: suscripción adicional de protección del dispositivo,
# TechSupport: suscripción adicional de soporte técnico, menor tiempo de espera,
# StreamingTV: suscripción de televisión por cable,
# StreamingMovies: suscripción de streaming de películas,
# Contract: tipo de contrato,
# PaperlessBilling: si el cliente prefiere recibir la factura en línea,
# PaymentMethod: forma de pago,
# Charges.Monthly: total de todos los servicios del cliente por mes,
# Charges.Total: total gastado por el cliente.

# %%
datos_telecom_expanded.tail()
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 7262          Yes                No             DSL  ...           No
# 7263          Yes               Yes     Fiber optic  ...           No
# 7264          Yes                No             DSL  ...          Yes
# 7265          Yes                No             DSL  ...           No
# 7266           No  No phone service             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
datos_telecom_expanded.shape
# Out:
# (7267, 21)

# %%
datos_telecom_expanded.isnull().sum()
# Out:
# customerID           0
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Charges.Monthly      0
# Charges.Total       11
# dtype: int64

# %%
null_charges_total = datos_telecom_expanded[datos_telecom_expanded['Charges.Total'].isnull()]
display(null_charges_total)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
# Cambio los nulos en 'Charges.Total' por 0
datos_telecom_expanded['Charges.Total'] = datos_telecom_expanded['Charges.Total'].fillna(0)
display(datos_telecom_expanded.isnull().sum())
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
senior_citizen_counts = datos_telecom_expanded['SeniorCitizen'].value_counts()
display(senior_citizen_counts)
# Out:
# SeniorCitizen
# 0    6085
# 1    1182
# Name: count, dtype: int64

# %%
churn_counts = datos_telecom_expanded['Churn'].value_counts()
display(churn_counts)
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
churn_empty = datos_telecom_expanded[datos_telecom_expanded['Churn'] == '']
print(f"Number of empty 'Churn' values: {len(churn_empty)}")
display(churn_empty)
# Out:
# Number of empty 'Churn' values: 224
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW        Female              0      No         No      11
# 75    0120-YZLQA          Male              0      No         No      71
# 96    0154-QYHJU          Male              0      No         No      29
# 98    0162-RZGMZ        Female              1      No         No       5
# 175   0274-VVQOQ          Male              1     Yes         No      65
# ...          ...   ...     ...            ...     ...        ...     ...
# 7158  9840-GSRFX        Female              0      No         No      14
# 7180  9872-RZQQB        Female              0     Yes         No      49
# 7211  9920-GNDMB          Male              0      No         No       9
# 7239  9955-RVWSC        Female              0     Yes        Yes      67
# 7247  9966-VYRTZ        Female              0     Yes        Yes      31
#
# ...

# %%
# clientes con facturacion se incluyeron en los que no dejaron la empresa
datos_telecom_expanded['Churn'] = datos_telecom_expanded['Churn'].replace('','No')
display(datos_telecom_expanded['Churn'].value_counts())
# Out:
# Churn
# No     5398
# Yes    1869
# Name: count, dtype: int64

# %%
(1869/7267)*100
# Out:
# 25.7190037154259

# %%
churn_no_zero_charges = datos_telecom_expanded[(datos_telecom_expanded['Churn'] == 'No') & ((datos_telecom_expanded['Charges.Monthly'] == 0)  | (datos_telecom_expanded['Charges.Total'] == 0))]
display(churn_no_zero_charges)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
datos_retirados = datos_telecom_expanded[datos_telecom_expanded['Churn'] == 'Yes']
display(datos_retirados.head())
# Out:
#     customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 2   0004-TLHLJ   Yes    Male              0      No         No       4
# 3   0011-IGKFF   Yes    Male              1     Yes         No      13
# 4   0013-EXCHZ   Yes  Female              1     Yes         No       3
# 18  0022-TCJCI   Yes    Male              1      No         No      45
# 19  0023-HGHWL   Yes    Male              1      No         No       1
#
#    PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 2           Yes                No     Fiber optic  ...           No
# 3           Yes                No     Fiber optic  ...          Yes
# 4           Yes                No     Fiber optic  ...           No
# 18          Yes                No             DSL  ...           No
# 19           No  No phone service             DSL  ...           No
#
#    DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
print(datos_retirados.shape[0])
# Out:
# 1869

# %%
total_monthly_charges_all = datos_telecom_expanded['Charges.Monthly'].sum()
total_total_charges_all = datos_telecom_expanded['Charges.Total'].sum()

print(f"Total Monthly Charges for all customers: ${total_monthly_charges_all:.2f}")
print(f"Total Total Charges for all customers: ${total_total_charges_all:.2f}")
# Out:
# Total Monthly Charges for all customers: $470320.95
# Total Total Charges for all customers: $16548281.85

# %%
total_monthly_charges_churned = datos_retirados['Charges.Monthly'].sum()
total_total_charges_churned = datos_retirados['Charges.Total'].sum()

print(f"Total Monthly Charges for churned customers: ${total_monthly_charges_churned:.2f}")
print(f"Total Total Charges for churned customers: ${total_total_charges_churned:.2f}")
# Out:
# Total Monthly Charges for churned customers: $139130.85
# Total Total Charges for churned customers: $2862926.90

# %%
categorical_columns = datos_telecom_expanded.select_dtypes(include='object').columns
columns_to_exclude = ['customerID', 'Churn']
# Exclude 'customerID' and 'Churn' as it will always be 'Yes' in datos_retirados

for col in categorical_columns:
    if col not in columns_to_exclude:
        print(f"Comparing '{col}':")
        print("Full Dataset:")
        display(datos_telecom_expanded[col].value_counts())
        print("\nChurned Customers Dataset:")
        display(datos_retirados[col].value_counts())
        print("-" * 30)
# Out:
# Comparing 'gender':
# Full Dataset:
# gender
# Male      3675
# Female    3592
# Name: count, dtype: int64
# Churned Customers Dataset:
# gender
# Female    939
# Male      930
# Name: count, dtype: int64
# ------------------------------
# Comparing 'Partner':
# Full Dataset:
# Partner
# No     3749
# Yes    3518
# Name: count, dtype: int64
# Churned Customers Dataset:
# Partner
# No     1200
# Yes     669
# Name: count, dtype: int64
# ------------------------------
# Comparing 'Dependents':
# Full Dataset:
# Dependents
# No     5086
# Yes    2181
# Name: count, dtype: int64
# Churned Customers Dataset:
# Dependents
# No     1543
# Yes     326
# Name: count, dtype: int64
# ------------------------------
# Comparing 'PhoneService':
# Full Dataset:
# PhoneService
# Yes    6560
# No      707
# Name: count, dtype: int64
# Churned Customers Dataset:
# PhoneService
# Yes    1699
# No      170
# Name: count, dtype: int64
# ------------------------------
# Comparing 'MultipleLines':
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
